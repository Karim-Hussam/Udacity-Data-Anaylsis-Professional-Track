# %%
import pandas as pd

# %%
data = pd.read_excel("C:\\Users\\DELL\\Desktop\\Alexandria's Weather.xlsx")
data = data.dropna()

# %%
data
# Out:
#     Days Name  Days Date Highest Temperature\n[AM , PM , Night]  \
# 1      Friday        3.0                     ['18', '20', '18']
# 3    Saturday        4.0                     ['18', '20', '19']
# 5      Sunday        5.0                     ['16', '19', '19']
# 7      Monday        6.0                     ['19', '21', '19']
# 9     Tuesday        7.0                     ['19', '21', '19']
# 11  Wednesday        8.0                     ['13', '16', '18']
# 13   Thursday        9.0                     ['19', '19', '19']
# 15     Friday       10.0                     ['18', '20', '18']
# 17   Saturday       11.0                     ['18', '19', '19']
# 19     Sunday       12.0                     ['19', '19', '18']
# 21     Monday       13.0                     ['17', '19', '17']
# 23    Tuesday       14.0                     ['19', '18', '18']
#
#    Lowest Temperature\n[AM , PM , Night] Wind\n[AM , PM , Night]  \
# 1                     ['17', '19', '16']       ['5', '10', '10']
# ...

# %%
data.to_excel("Alexandria's Weahter.xlsx", sheet_name='Next 2 Weeks')
